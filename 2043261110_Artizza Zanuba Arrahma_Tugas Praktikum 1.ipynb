# %%
total_barang=1250
kapasitas_kardus=45
kardus_penuh=total_barang//kapasitas_kardus
sisa_barang=total_barang%kapasitas_kardus

print(f"Jumlah kardus penuh:{kardus_penuh}")
print(f"Sisa barang:{sisa_barang}")
# Out:
# Jumlah kardus penuh:27
# Sisa barang:35

# %%
skor_produk=85
skor_layanan=70
nilai_akhir=(skor_produk*0.6)+(skor_layanan*0.4)
print(f"Nilai Akhir: {int(nilai_akhir)}")
# Out:
# Nilai Akhir: 79

# %%
biaya_pesanan=50000
kebutuhan_tahunan=1000
biaya_simpan=400
eoq=((2*biaya_pesanan*kebutuhan_tahunan)/biaya_simpan)**0.5
print(f"Nilai EOQ: {int(eoq)}")
# Out:
# Nilai EOQ: 500

# %%
kata1=("Statistika")
kata2=("Bisnis")
kata3=("ITS")
print(f"{kata1} {kata2} {kata3}")
# Out:
# Statistika Bisnis ITS

# %%
departemen="Statistika bisnis"
print(departemen[0])
print(departemen[-1])
# Out:
# S
# s

# %%
matkul="Analisis Data Eksploratif"
kata=matkul[9:13]
print(kata)
# Out:
# Data

# %%
nama_matkul="aLgoRitmA pEmroGramAn"
hasil=nama_matkul.title()
print(hasil)
# Out:
# Algoritma Pemrograman

# %%
teks="Mahasiswa DSB kelas 1C sangat senang belajar ALPROG"
hasil1=len(teks)
hasil2=teks.count("a")
print(f"Jumlah karakter ada: {hasil1}")
print(f"Jumlah huruf a kecil ada: {hasil2}")
# Out:
# Jumlah karakter ada: 51
# Jumlah huruf a kecil ada: 9

# %%
panjang_max=100
lebar_kolom=4
jumlah_kolom=panjang_max//lebar_kolom
garis_pemisah="="*jumlah_kolom
print(f"Jumlah kolom ada: {jumlah_kolom}")
print(garis_pemisah)
# Out:
# Jumlah kolom ada: 25
# ...

# %%
anggaran=50000
pengeluaran=35000
pesan1="Sisa saldo Anda adalah Rp"
sisa_saldo=str(anggaran-pengeluaran)
pesan2=pesan1+sisa_saldo
print(pesan2)
# Out:
# Sisa saldo Anda adalah Rp15000
